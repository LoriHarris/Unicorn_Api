# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
import json
import logging
import csv


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#REMEMBER to change sample_cities back to cities when running for official hw
url = "http://api.openweathermap.org/data/2.5/weather?"
sample_cities = ["Paris", "Raleigh", "New York", "Seattle"]
print(f"Beginning Data Retrieval")
print(f"----------------------------")
count1 = []
data = []
temperatures = []
cloudiness = []
country = []
humidity = []
lat = []
lon = []
max_temp = []
wind = []
date = []
cities2 = []
for x in cities:
    if x not in count1:
        count1.append(x)
        count2 = str((len(count1)))
        name = x
    try:
        print(f"Processing record " + count2 + "  of Set 1 |" + name)
        query_url = url + "appid=" + api_key + "&q=" + name
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        data.append(weather_json)
        temperatures.append(weather_json["main"]["temp"])  
        cloudiness.append(weather_json["clouds"]["all"])
        country.append(weather_json["sys"]["country"])
        humidity.append(weather_json["main"]["humidity"])
        lat.append(weather_json["coord"]["lat"])
        lon.append(weather_json["coord"]["lon"])
        max_temp.append(weather_json["main"]["temp_max"])
        wind.append(weather_json["wind"]["speed"])
        date.append(weather_json["dt"])
        cities2.append(weather_json["name"])
    except KeyError:
        print("City not found, skipping....")
print(f"----------------------------")
print(f"Data Retrieval Complete")
print(f"----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 1  of Set 1 |chapleau
# Processing record 2  of Set 1 |vaini
# Processing record 3  of Set 1 |bluff
# Processing record 4  of Set 1 |schwabach
# Processing record 5  of Set 1 |shitanjing
# Processing record 6  of Set 1 |yulara
# Processing record 7  of Set 1 |punta arenas
# Processing record 8  of Set 1 |saint-philippe
# Processing record 9  of Set 1 |mahebourg
# Processing record 10  of Set 1 |eldorado
# Processing record 11  of Set 1 |puerto ayora
# Processing record 12  of Set 1 |keningau
# Processing record 13  of Set 1 |upernavik
# Processing record 14  of Set 1 |adre
# Processing record 15  of Set 1 |souillac
# Processing record 16  of Set 1 |talnakh
# Processing record 17  of Set 1 |karaul
# City not found, skipping....
# Processing record 18  of Set 1 |qaanaaq
# Processing record 19  of Set 1 |bargal
# City not found, skipping....
# Processing record 20  of Set 1 |jamestown
# Processing record 21  of Set 1 |tiksi
# Processing record 22  of Set 1 |albany
# Processing record 23  of Set 1 |san policarpo
# Processing record 24  of Set 1 |doha
# Processing record 25  of Set 1 |erdenet
# Processing record 26  of Set 1 |unai
# Processing record 27  of Set 1 |samusu
# City not found, skipping....
# Processing record 28  of Set 1 |lompoc
# Processing record 29  of Set 1 |iqaluit
# Processing record 30  of Set 1 |belmonte
# Processing record 31  of Set 1 |tuatapere
# Processing record 32  of Set 1 |butaritari
# Processing record 33  of Set 1 |ponta do sol
# Processing record 34  of Set 1 |santa rosalia
# Processing record 35  of Set 1 |gorontalo
# Processing record 36  of Set 1 |kapaa
# Processing record 37  of Set 1 |hamilton
# Processing record 38  of Set 1 |ushuaia
# Processing record 39  of Set 1 |praia da vitoria
# Processing record 40  of Set 1 |rikitea
# Processing record 41  of Set 1 |hilo
# Processing record 42  of Set 1 |olinda
# Processing record 43  of Set 1 |new norfolk
# Processing record 44  of Set 1 |hualmay
# Processing record 45  of Set 1 |teahupoo
# Processing record 46  of Set 1 |kyshtovka
# Processing record 47  of Set 1 |kodiak
# Processing record 48  of Set 1 |kazalinsk
# City not found, skipping....
# Processing record 49  of Set 1 |slave lake
# Processing record 50  of Set 1 |omboue
# Processing record 51  of Set 1 |richards bay
# Processing record 52  of Set 1 |karkaralinsk
# City not found, skipping....
# Processing record 53  of Set 1 |torbay
# Processing record 54  of Set 1 |eureka
# Processing record 55  of Set 1 |erenhot
# Processing record 56  of Set 1 |thompson
# Processing record 57  of Set 1 |sakaraha
# Processing record 58  of Set 1 |algeciras
# Processing record 59  of Set 1 |kaitangata
# Processing record 60  of Set 1 |norman wells
# Processing record 61  of Set 1 |genhe
# Processing record 62  of Set 1 |avarua
# Processing record 63  of Set 1 |mezen
# Processing record 64  of Set 1 |bitung
# Processing record 65  of Set 1 |hermanus
# Processing record 66  of Set 1 |taolanaro
# City not found, skipping....
# Processing record 67  of Set 1 |odweyne
# City not found, skipping....
# Processing record 68  of Set 1 |ribeira grande
# Processing record 69  of Set 1 |batticaloa
# Processing record 70  of Set 1 |mount isa
# Processing record 71  of Set 1 |castro
# Processing record 72  of Set 1 |barrow
# Processing record 73  of Set 1 |hit
# Processing record 74  of Set 1 |abeche
# Processing record 75  of Set 1 |grindavik
# Processing record 76  of Set 1 |severo-kurilsk
# Processing record 77  of Set 1 |nanortalik
# Processing record 78  of Set 1 |carnarvon
# Processing record 79  of Set 1 |mataura
# Processing record 80  of Set 1 |busselton
# Processing record 81  of Set 1 |atuona
# Processing record 82  of Set 1 |nago
# Processing record 83  of Set 1 |la palma
# Processing record 84  of Set 1 |alta floresta
# Processing record 85  of Set 1 |port elizabeth
# Processing record 86  of Set 1 |zabol
# Processing record 87  of Set 1 |fairbanks
# Processing record 88  of Set 1 |kollo
# Processing record 89  of Set 1 |yurimaguas
# Processing record 90  of Set 1 |karatau
# Processing record 91  of Set 1 |mar del plata
# Processing record 92  of Set 1 |port lincoln
# Processing record 93  of Set 1 |rochefort
# Processing record 94  of Set 1 |logstor
# Processing record 95  of Set 1 |codrington
# Processing record 96  of Set 1 |georgetown
# Processing record 97  of Set 1 |kavieng
# Processing record 98  of Set 1 |tuktoyaktuk
# Processing record 99  of Set 1 |kyra
# City not found, skipping....
# Processing record 100  of Set 1 |khatanga
# Processing record 101  of Set 1 |yarmouth
# Processing record 102  of Set 1 |yellowknife
# Processing record 103  of Set 1 |umzimvubu
# City not found, skipping....
# Processing record 104  of Set 1 |normal
# Processing record 105  of Set 1 |hobart
# Processing record 106  of Set 1 |deputatskiy
# Processing record 107  of Set 1 |akyab
# City not found, skipping....
# Processing record 108  of Set 1 |tumannyy
# City not found, skipping....
# Processing record 109  of Set 1 |vuktyl
# Processing record 110  of Set 1 |ucluelet
# Processing record 111  of Set 1 |cidreira
# Processing record 112  of Set 1 |esperance
# Processing record 113  of Set 1 |cairns
# Processing record 114  of Set 1 |anadyr
# Processing record 115  of Set 1 |marawi
# Processing record 116  of Set 1 |banff
# Processing record 117  of Set 1 |arraial do cabo
# Processing record 118  of Set 1 |tasiilaq
# Processing record 119  of Set 1 |milos
# Processing record 120  of Set 1 |hithadhoo
# Processing record 121  of Set 1 |thomaston
# Processing record 122  of Set 1 |bosaso
# Processing record 123  of Set 1 |grand gaube
# Processing record 124  of Set 1 |batetskiy
# Processing record 125  of Set 1 |manzil tamim
# City not found, skipping....
# Processing record 126  of Set 1 |pak phanang
# Processing record 127  of Set 1 |falealupo
# City not found, skipping....
# Processing record 128  of Set 1 |bredasdorp
# Processing record 129  of Set 1 |meiganga
# Processing record 130  of Set 1 |chengmai
# City not found, skipping....
# Processing record 131  of Set 1 |east london
# Processing record 132  of Set 1 |lavrentiya
# Processing record 133  of Set 1 |pemangkat
# City not found, skipping....
# Processing record 134  of Set 1 |lac du bonnet
# Processing record 135  of Set 1 |hire
# City not found, skipping....
# Processing record 136  of Set 1 |ancud
# Processing record 137  of Set 1 |bilma
# Processing record 138  of Set 1 |port alfred
# Processing record 139  of Set 1 |bengkulu
# City not found, skipping....
# Processing record 140  of Set 1 |clyde river
# Processing record 141  of Set 1 |renqiu
# Processing record 142  of Set 1 |cape town
# Processing record 143  of Set 1 |khorixas
# Processing record 144  of Set 1 |melfi
# Processing record 145  of Set 1 |grand river south east
# City not found, skipping....
# Processing record 146  of Set 1 |inirida
# Processing record 147  of Set 1 |hervey bay
# Processing record 148  of Set 1 |ha giang
# Processing record 149  of Set 1 |oyon
# Processing record 150  of Set 1 |gangotri
# City not found, skipping....
# Processing record 151  of Set 1 |carbonia
# Processing record 152  of Set 1 |caravelas
# Processing record 153  of Set 1 |dzaoudzi
# Processing record 154  of Set 1 |dikson
# Processing record 155  of Set 1 |korem
# Processing record 156  of Set 1 |mys shmidta
# City not found, skipping....
# Processing record 157  of Set 1 |yumen
# Processing record 158  of Set 1 |faya
# Processing record 159  of Set 1 |petrolia
# Processing record 160  of Set 1 |pisco
# Processing record 161  of Set 1 |amderma
# City not found, skipping....
# Processing record 162  of Set 1 |kainantu
# Processing record 163  of Set 1 |betare oya
# Processing record 164  of Set 1 |lebu
# Processing record 165  of Set 1 |provideniya
# Processing record 166  of Set 1 |zlobin
# Processing record 167  of Set 1 |sola
# Processing record 168  of Set 1 |bombay
# Processing record 169  of Set 1 |luyang
# Processing record 170  of Set 1 |sitka
# Processing record 171  of Set 1 |longyearbyen
# Processing record 172  of Set 1 |amilly
# Processing record 173  of Set 1 |mahadday weyne
# City not found, skipping....
# Processing record 174  of Set 1 |illoqqortoormiut
# City not found, skipping....
# Processing record 175  of Set 1 |rio gallegos
# Processing record 176  of Set 1 |anamur
# Processing record 177  of Set 1 |gizo
# Processing record 178  of Set 1 |barcelos
# Processing record 179  of Set 1 |sant feliu de guixols
# Processing record 180  of Set 1 |balancan
# City not found, skipping....
# Processing record 181  of Set 1 |salalah
# Processing record 182  of Set 1 |ballina
# Processing record 183  of Set 1 |mango
# Processing record 184  of Set 1 |marcona
# City not found, skipping....
# Processing record 185  of Set 1 |tadine
# Processing record 186  of Set 1 |formosa do rio preto
# Processing record 187  of Set 1 |cabo san lucas
# Processing record 188  of Set 1 |severobaykalsk
# Processing record 189  of Set 1 |saskylakh
# Processing record 190  of Set 1 |attawapiskat
# City not found, skipping....
# Processing record 191  of Set 1 |haines junction
# Processing record 192  of Set 1 |novikovo
# Processing record 193  of Set 1 |baykit
# Processing record 194  of Set 1 |faanui
# Processing record 195  of Set 1 |vila velha
# Processing record 196  of Set 1 |isangel
# Processing record 197  of Set 1 |nizhneyansk
# City not found, skipping....
# Processing record 198  of Set 1 |tarhunah
# City not found, skipping....
# Processing record 199  of Set 1 |kizhinga
# Processing record 200  of Set 1 |saldanha
# Processing record 201  of Set 1 |manggar
# Processing record 202  of Set 1 |bethel
# Processing record 203  of Set 1 |nikolskoye
# Processing record 204  of Set 1 |chuy
# Processing record 205  of Set 1 |maloshuyka
# City not found, skipping....
# Processing record 206  of Set 1 |vilyuysk
# Processing record 207  of Set 1 |miaray
# Processing record 208  of Set 1 |kamenka
# Processing record 209  of Set 1 |barentsburg
# City not found, skipping....
# Processing record 210  of Set 1 |beyneu
# Processing record 211  of Set 1 |maragogi
# Processing record 212  of Set 1 |antofagasta
# Processing record 213  of Set 1 |enid
# Processing record 214  of Set 1 |tessalit
# Processing record 215  of Set 1 |suntar
# Processing record 216  of Set 1 |pevek
# Processing record 217  of Set 1 |saraland
# Processing record 218  of Set 1 |khasan
# Processing record 219  of Set 1 |arecibo
# Processing record 220  of Set 1 |hasaki
# Processing record 221  of Set 1 |lagoa
# Processing record 222  of Set 1 |palu
# Processing record 223  of Set 1 |cockburn town
# Processing record 224  of Set 1 |nabire
# Processing record 225  of Set 1 |saleaula
# City not found, skipping....
# Processing record 226  of Set 1 |otradnoye
# Processing record 227  of Set 1 |kapit
# Processing record 228  of Set 1 |neryungri
# Processing record 229  of Set 1 |motala
# Processing record 230  of Set 1 |poum
# Processing record 231  of Set 1 |tuggurt
# City not found, skipping....
# Processing record 232  of Set 1 |san quintin
# Processing record 233  of Set 1 |san patricio
# Processing record 234  of Set 1 |rio grande
# Processing record 235  of Set 1 |moose factory
# Processing record 236  of Set 1 |te anau
# Processing record 237  of Set 1 |skjervoy
# Processing record 238  of Set 1 |coihaique
# Processing record 239  of Set 1 |port hardy
# Processing record 240  of Set 1 |callaway
# Processing record 241  of Set 1 |takoradi
# Processing record 242  of Set 1 |riachao das neves
# Processing record 243  of Set 1 |shalya
# Processing record 244  of Set 1 |belen
# Processing record 245  of Set 1 |waingapu
# Processing record 246  of Set 1 |kenai
# Processing record 247  of Set 1 |fort nelson
# Processing record 248  of Set 1 |vanavara
# Processing record 249  of Set 1 |nhulunbuy
# Processing record 250  of Set 1 |tura
# Processing record 251  of Set 1 |porto novo
# Processing record 252  of Set 1 |saint george
# Processing record 253  of Set 1 |porirua
# Processing record 254  of Set 1 |gat
# Processing record 255  of Set 1 |grand-santi
# Processing record 256  of Set 1 |churhat
# Processing record 257  of Set 1 |bonthe
# Processing record 258  of Set 1 |marsa matruh
# Processing record 259  of Set 1 |baiyin
# Processing record 260  of Set 1 |havre-saint-pierre
# Processing record 261  of Set 1 |zhezkazgan
# Processing record 262  of Set 1 |la ronge
# Processing record 263  of Set 1 |kankaanpaa
# Processing record 264  of Set 1 |black river
# Processing record 265  of Set 1 |port hedland
# Processing record 266  of Set 1 |bambous virieux
# Processing record 267  of Set 1 |santa maria
# Processing record 268  of Set 1 |yerbogachen
# Processing record 269  of Set 1 |adrar
# Processing record 270  of Set 1 |vypolzovo
# Processing record 271  of Set 1 |kargasok
# Processing record 272  of Set 1 |venafro
# Processing record 273  of Set 1 |vostok
# Processing record 274  of Set 1 |aberdeen
# Processing record 275  of Set 1 |causapscal
# Processing record 276  of Set 1 |nahavand
# Processing record 277  of Set 1 |great bend
# Processing record 278  of Set 1 |tabiauea
# City not found, skipping....
# Processing record 279  of Set 1 |lahaina
# Processing record 280  of Set 1 |acapulco
# Processing record 281  of Set 1 |teknaf
# Processing record 282  of Set 1 |chifeng
# Processing record 283  of Set 1 |manicore
# Processing record 284  of Set 1 |matucana
# Processing record 285  of Set 1 |kloulklubed
# Processing record 286  of Set 1 |rafsanjan
# Processing record 287  of Set 1 |tazovskiy
# Processing record 288  of Set 1 |anqing
# Processing record 289  of Set 1 |birao
# Processing record 290  of Set 1 |victoria
# Processing record 291  of Set 1 |catia la mar
# Processing record 292  of Set 1 |chokurdakh
# Processing record 293  of Set 1 |griffith
# Processing record 294  of Set 1 |santa maria da vitoria
# Processing record 295  of Set 1 |tatvan
# Processing record 296  of Set 1 |road town
# Processing record 297  of Set 1 |potiskum
# Processing record 298  of Set 1 |santa ana
# Processing record 299  of Set 1 |belle fourche
# Processing record 300  of Set 1 |boende
# Processing record 301  of Set 1 |lorengau
# Processing record 302  of Set 1 |ust-kamchatsk
# City not found, skipping....
# Processing record 303  of Set 1 |rehti
# Processing record 304  of Set 1 |vallenar
# Processing record 305  of Set 1 |namatanai
# Processing record 306  of Set 1 |luau
# Processing record 307  of Set 1 |namibe
# Processing record 308  of Set 1 |airai
# Processing record 309  of Set 1 |hokitika
# Processing record 310  of Set 1 |helena
# Processing record 311  of Set 1 |sudbury
# Processing record 312  of Set 1 |klaksvik
# Processing record 313  of Set 1 |svolvaer
# Processing record 314  of Set 1 |sentyabrskiy
# City not found, skipping....
# Processing record 315  of Set 1 |sechura
# Processing record 316  of Set 1 |camana
# City not found, skipping....
# Processing record 317  of Set 1 |kem
# Processing record 318  of Set 1 |gulshat
# City not found, skipping....
# Processing record 319  of Set 1 |bara
# Processing record 320  of Set 1 |verin
# Processing record 321  of Set 1 |melun
# Processing record 322  of Set 1 |havre
# Processing record 323  of Set 1 |los llanos de aridane
# Processing record 324  of Set 1 |alamosa
# Processing record 325  of Set 1 |najran
# Processing record 326  of Set 1 |amnat charoen
# Processing record 327  of Set 1 |benito juarez
# Processing record 328  of Set 1 |luderitz
# Processing record 329  of Set 1 |ugoofaaru
# Processing record 330  of Set 1 |rawannawi
# City not found, skipping....
# Processing record 331  of Set 1 |sobradinho
# Processing record 332  of Set 1 |sayula
# Processing record 333  of Set 1 |sinnamary
# Processing record 334  of Set 1 |copiapo
# Processing record 335  of Set 1 |vikhorevka
# Processing record 336  of Set 1 |toul
# Processing record 337  of Set 1 |sinegorye
# Processing record 338  of Set 1 |halifax
# Processing record 339  of Set 1 |anapskaya
# Processing record 340  of Set 1 |nguiu
# City not found, skipping....
# Processing record 341  of Set 1 |plettenberg bay
# Processing record 342  of Set 1 |ilulissat
# Processing record 343  of Set 1 |caconda
# Processing record 344  of Set 1 |college
# Processing record 345  of Set 1 |buncrana
# Processing record 346  of Set 1 |yarada
# Processing record 347  of Set 1 |katsuura
# Processing record 348  of Set 1 |foki
# Processing record 349  of Set 1 |gra liyia
# Processing record 350  of Set 1 |burica
# City not found, skipping....
# Processing record 351  of Set 1 |san carlos de bariloche
# Processing record 352  of Set 1 |pangai
# Processing record 353  of Set 1 |zyryanka
# Processing record 354  of Set 1 |port blair
# Processing record 355  of Set 1 |sangar
# Processing record 356  of Set 1 |talara
# Processing record 357  of Set 1 |whitehorse
# Processing record 358  of Set 1 |gazanjyk
# Processing record 359  of Set 1 |ostrovnoy
# Processing record 360  of Set 1 |rawson
# Processing record 361  of Set 1 |west plains
# Processing record 362  of Set 1 |shache
# Processing record 363  of Set 1 |constitucion
# Processing record 364  of Set 1 |baruun-urt
# Processing record 365  of Set 1 |meulaboh
# Processing record 366  of Set 1 |lashio
# Processing record 367  of Set 1 |saint-augustin
# Processing record 368  of Set 1 |shwebo
# Processing record 369  of Set 1 |port pirie
# Processing record 370  of Set 1 |paita
# Processing record 371  of Set 1 |labuhan
# Processing record 372  of Set 1 |mpika
# Processing record 373  of Set 1 |henties bay
# Processing record 374  of Set 1 |ust-nera
# Processing record 375  of Set 1 |bilibino
# Processing record 376  of Set 1 |mirabad
# Processing record 377  of Set 1 |klyuchi
# Processing record 378  of Set 1 |svobodnyy
# Processing record 379  of Set 1 |kabare
# Processing record 380  of Set 1 |dibaya
# City not found, skipping....
# Processing record 381  of Set 1 |coalcoman
# City not found, skipping....
# Processing record 382  of Set 1 |wanaka
# Processing record 383  of Set 1 |nuevo progreso
# Processing record 384  of Set 1 |vestmannaeyjar
# Processing record 385  of Set 1 |mlalo
# Processing record 386  of Set 1 |nakhon phanom
# Processing record 387  of Set 1 |sao gabriel da cachoeira
# Processing record 388  of Set 1 |luena
# Processing record 389  of Set 1 |lenger
# Processing record 390  of Set 1 |jian
# Processing record 391  of Set 1 |mitsamiouli
# Processing record 392  of Set 1 |gopalganj
# Processing record 393  of Set 1 |rudsar
# Processing record 394  of Set 1 |tokzar
# City not found, skipping....
# Processing record 395  of Set 1 |husavik
# Processing record 396  of Set 1 |akkudah
# City not found, skipping....
# Processing record 397  of Set 1 |honningsvag
# Processing record 398  of Set 1 |okha
# Processing record 399  of Set 1 |sankheda
# Processing record 400  of Set 1 |newport
# Processing record 401  of Set 1 |mildura
# Processing record 402  of Set 1 |flinders
# Processing record 403  of Set 1 |west wendover
# Processing record 404  of Set 1 |srednekolymsk
# Processing record 405  of Set 1 |vredendal
# Processing record 406  of Set 1 |necochea
# Processing record 407  of Set 1 |pangnirtung
# Processing record 408  of Set 1 |south sioux city
# Processing record 409  of Set 1 |broome
# Processing record 410  of Set 1 |maningrida
# Processing record 411  of Set 1 |opuwo
# Processing record 412  of Set 1 |bowen
# Processing record 413  of Set 1 |leningradskiy
# Processing record 414  of Set 1 |sonoita
# Processing record 415  of Set 1 |nara
# Processing record 416  of Set 1 |sajanan
# Processing record 417  of Set 1 |sao geraldo do araguaia
# Processing record 418  of Set 1 |ingham
# Processing record 419  of Set 1 |kiunga
# Processing record 420  of Set 1 |sao filipe
# Processing record 421  of Set 1 |havelock
# Processing record 422  of Set 1 |tezu
# Processing record 423  of Set 1 |san andres
# Processing record 424  of Set 1 |belushya guba
# City not found, skipping....
# Processing record 425  of Set 1 |hinton
# Processing record 426  of Set 1 |makakilo city
# Processing record 427  of Set 1 |rungata
# City not found, skipping....
# Processing record 428  of Set 1 |yialos
# City not found, skipping....
# Processing record 429  of Set 1 |botwood
# Processing record 430  of Set 1 |tenenkou
# Processing record 431  of Set 1 |nemuro
# Processing record 432  of Set 1 |jalu
# Processing record 433  of Set 1 |kigonsera
# Processing record 434  of Set 1 |kamenskoye
# City not found, skipping....
# Processing record 435  of Set 1 |mehamn
# Processing record 436  of Set 1 |matagami
# Processing record 437  of Set 1 |puerto colombia
# Processing record 438  of Set 1 |namwala
# Processing record 439  of Set 1 |tromso
# Processing record 440  of Set 1 |vao
# Processing record 441  of Set 1 |hofn
# Processing record 442  of Set 1 |zaterechnyy
# Processing record 443  of Set 1 |itarema
# Processing record 444  of Set 1 |imbituba
# Processing record 445  of Set 1 |karratha
# Processing record 446  of Set 1 |margate
# Processing record 447  of Set 1 |chandpur
# Processing record 448  of Set 1 |lenoir city
# Processing record 449  of Set 1 |ovruch
# Processing record 450  of Set 1 |portland
# Processing record 451  of Set 1 |ulaangom
# Processing record 452  of Set 1 |qaqortoq
# Processing record 453  of Set 1 |ovalle
# Processing record 454  of Set 1 |tupaciguara
# Processing record 455  of Set 1 |saint-paul-les-dax
# Processing record 456  of Set 1 |angoche
# Processing record 457  of Set 1 |axim
# Processing record 458  of Set 1 |ponta delgada
# Processing record 459  of Set 1 |pizarro
# Processing record 460  of Set 1 |bundaberg
# Processing record 461  of Set 1 |okhotsk
# Processing record 462  of Set 1 |sembe
# City not found, skipping....
# Processing record 463  of Set 1 |sibolga
# Processing record 464  of Set 1 |babanusah
# City not found, skipping....
# Processing record 465  of Set 1 |vila
# Processing record 466  of Set 1 |caribou
# Processing record 467  of Set 1 |sovetskiy
# Processing record 468  of Set 1 |adeje
# Processing record 469  of Set 1 |rumuruti
# Processing record 470  of Set 1 |qasigiannguit
# Processing record 471  of Set 1 |beloha
# Processing record 472  of Set 1 |pedasi
# Processing record 473  of Set 1 |vylgort
# City not found, skipping....
# Processing record 474  of Set 1 |aykhal
# Processing record 475  of Set 1 |yeppoon
# Processing record 476  of Set 1 |port macquarie
# Processing record 477  of Set 1 |murgab
# Processing record 478  of Set 1 |davila
# Processing record 479  of Set 1 |ulaanbaatar
# Processing record 480  of Set 1 |hay river
# Processing record 481  of Set 1 |daru
# Processing record 482  of Set 1 |puerto suarez
# Processing record 483  of Set 1 |balabac
# Processing record 484  of Set 1 |barranca
# Processing record 485  of Set 1 |miri
# Processing record 486  of Set 1 |jumla
# Processing record 487  of Set 1 |nouadhibou
# Processing record 488  of Set 1 |eirunepe
# Processing record 489  of Set 1 |kudahuvadhoo
# Processing record 490  of Set 1 |cherskiy
# Processing record 491  of Set 1 |mto wa mbu
# Processing record 492  of Set 1 |kholtoson
# Processing record 493  of Set 1 |vyartsilya
# Processing record 494  of Set 1 |concordia
# Processing record 495  of Set 1 |kendari
# Processing record 496  of Set 1 |svetlogorsk
# Processing record 497  of Set 1 |malwan
# City not found, skipping....
# Processing record 498  of Set 1 |alice springs
# Processing record 499  of Set 1 |mudu
# Processing record 500  of Set 1 |chauk
# Processing record 501  of Set 1 |san francisco
# Processing record 502  of Set 1 |north bend
# Processing record 503  of Set 1 |manono
# Processing record 504  of Set 1 |rocha
# Processing record 505  of Set 1 |mwinilunga
# Processing record 506  of Set 1 |vigrestad
# Processing record 507  of Set 1 |tsihombe
# City not found, skipping....
# Processing record 508  of Set 1 |kavaratti
# Processing record 509  of Set 1 |nyuzen
# Processing record 510  of Set 1 |aksu
# Processing record 511  of Set 1 |manokwari
# Processing record 512  of Set 1 |dedza
# Processing record 513  of Set 1 |praia
# Processing record 514  of Set 1 |mana
# Processing record 515  of Set 1 |stefanesti
# Processing record 516  of Set 1 |kahului
# Processing record 517  of Set 1 |bonavista
# Processing record 518  of Set 1 |aksarka
# Processing record 519  of Set 1 |louis trichardt
# Processing record 520  of Set 1 |darhan
# Processing record 521  of Set 1 |fukue
# Processing record 522  of Set 1 |inhambane
# Processing record 523  of Set 1 |chaykovskaya
# Processing record 524  of Set 1 |saint anthony
# Processing record 525  of Set 1 |padrauna
# Processing record 526  of Set 1 |sisimiut
# Processing record 527  of Set 1 |narsaq
# Processing record 528  of Set 1 |paamiut
# Processing record 529  of Set 1 |olafsvik
# City not found, skipping....
# Processing record 530  of Set 1 |orbetello
# Processing record 531  of Set 1 |jacareacanga
# Processing record 532  of Set 1 |pafos
# City not found, skipping....
# Processing record 533  of Set 1 |shulan
# Processing record 534  of Set 1 |svarstad
# Processing record 535  of Set 1 |vastseliina
# Processing record 536  of Set 1 |zhanakorgan
# Processing record 537  of Set 1 |aklavik
# Processing record 538  of Set 1 |umea
# Processing record 539  of Set 1 |palana
# Processing record 540  of Set 1 |brae
# Processing record 541  of Set 1 |karamay
# City not found, skipping....
# Processing record 542  of Set 1 |forssa
# Processing record 543  of Set 1 |xochitlan
# Processing record 544  of Set 1 |pontes e lacerda
# Processing record 545  of Set 1 |indramayu
# Processing record 546  of Set 1 |price
# Processing record 547  of Set 1 |kamaishi
# Processing record 548  of Set 1 |luwuk
# Processing record 549  of Set 1 |ternate
# Processing record 550  of Set 1 |nichinan
# Processing record 551  of Set 1 |rio branco
# Processing record 552  of Set 1 |poya
# Processing record 553  of Set 1 |vysokopillya
# Processing record 554  of Set 1 |preeceville
# Processing record 555  of Set 1 |quatre cocos
# Processing record 556  of Set 1 |girona
# Processing record 557  of Set 1 |malanje
# Processing record 558  of Set 1 |ocos
# Processing record 559  of Set 1 |moulins
# Processing record 560  of Set 1 |half moon bay
# Processing record 561  of Set 1 |asau
# City not found, skipping....
# Processing record 562  of Set 1 |gamboula
# Processing record 563  of Set 1 |el doncello
# Processing record 564  of Set 1 |sabang
# Processing record 565  of Set 1 |vaitupu
# City not found, skipping....
# Processing record 566  of Set 1 |utiroa
# City not found, skipping....
# Processing record 567  of Set 1 |dingle
# Processing record 568  of Set 1 |porto seguro
# Processing record 569  of Set 1 |remagen
# Processing record 570  of Set 1 |diyarb najm
# Processing record 571  of Set 1 |swift current
# Processing record 572  of Set 1 |glazunovka
# Processing record 573  of Set 1 |muros
# Processing record 574  of Set 1 |beringovskiy
# Processing record 575  of Set 1 |uwayl
# City not found, skipping....
# Processing record 576  of Set 1 |rantepao
# Processing record 577  of Set 1 |tabou
# Processing record 578  of Set 1 |cam ranh
# Processing record 579  of Set 1 |lebyazhye
# Processing record 580  of Set 1 |flin flon
# Processing record 581  of Set 1 |biak
# Processing record 582  of Set 1 |hami
# Processing record 583  of Set 1 |krasnoarmeysk
# Processing record 584  of Set 1 |sao jose da tapera
# Processing record 585  of Set 1 |touros
# Processing record 586  of Set 1 |zhigansk
# Processing record 587  of Set 1 |umm kaddadah
# Processing record 588  of Set 1 |saint-paul
# Processing record 589  of Set 1 |naftah
# City not found, skipping....
# Processing record 590  of Set 1 |camapua
# Processing record 591  of Set 1 |mecca
# Processing record 592  of Set 1 |vysokogornyy
# Processing record 593  of Set 1 |myitkyina
# Processing record 594  of Set 1 |huarmey
# Processing record 595  of Set 1 |roma
# Processing record 596  of Set 1 |saint-pierre
# Processing record 597  of Set 1 |caxito
# Processing record 598  of Set 1 |arauca
# Processing record 599  of Set 1 |kralendijk
# Processing record 600  of Set 1 |andenes
# City not found, skipping....
# Processing record 601  of Set 1 |menongue
# Processing record 602  of Set 1 |basco
# Processing record 603  of Set 1 |ginda
# Processing record 604  of Set 1 |mount darwin
# Processing record 605  of Set 1 |gornopravdinsk
# Processing record 606  of Set 1 |springbok
# Processing record 607  of Set 1 |devils lake
# Processing record 608  of Set 1 |geraldton
# Processing record 609  of Set 1 |camacupa
# Processing record 610  of Set 1 |bennington
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#read in raw data to json format, create csv file

raw_data = json.dumps(data, indent=4, sort_keys=False)
raw_data1 = pd.read_json(raw_data, typ='series')
weather_csv = open("weather.csv", "w")
csvwriter = csv.writer(weather_csv)

# %%
#create json file an write rawdata to it, export as.json
data = open('weather.json', 'w')
data.write(raw_data)
data.close()

# %%
#put info in dataframe object, export to csv
data1 = pd.read_json("weather.json")
data1.to_csv("weather.csv")

# %%
data2 = {
    "City":cities2,
    "Country": country,
    "Temperature": temperatures,
    "Clouds": cloudiness,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temp": max_temp,
    "Wind Speed": wind,
    "Date": date,
}

data3 = pd.DataFrame(data2)
data3.head()
# Out:
#          City Country  Temperature  Clouds  Humidity  Latitude  Longitude  \
# 0    Chapleau      CA      257.150      20        77     47.85     -83.40
# 1       Vaini      IN      294.307       0        68     15.34      74.49
# 2       Bluff      AU      297.107       0        61    -23.58     149.07
# 3   Schwabach      DE      278.510      75        93     49.33      11.02
# 4  Shitanjing      CN      258.757       0        61     39.23     106.34
#
#    Max Temp  Wind Speed        Date
# 0   257.150        3.10  1547395200
# 1   294.307        0.66  1547396848
# 2   297.107        5.51  1547396836
# 3   279.950        8.70  1547394960
# 4   258.757        1.11  1547396954

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data3["Latitude"], data3["Max Temp"], marker="o", facecolors="blue", edgecolors="black", s=75, alpha=.5)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("City Latitude vs. Max Temperature")
plt.savefig("lat_v_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data3["Latitude"], data3["Humidity"], marker="o", facecolors="blue", edgecolors="black", s=75, alpha=.5)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity")
plt.savefig("lat_v_humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data3["Latitude"], data3["Clouds"], marker="o", facecolors="blue", edgecolors="black", s=75, alpha=.5)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness")
plt.savefig("lat_v_clouds.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data3["Latitude"], data3["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", s=75, alpha = .5)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed")
plt.savefig("lat_v_wind.png")
plt.show()

# %%
#NOTED:  See plot and subsequent DF
#There was one crazy outlier in my humidity plot. 
#When I re-ran the random cities, it dissapeared, but I saved the info
#Here it is below, I thought it was interesting:
#used .loc to get the details on it
#Paita humidity levels were almost 300%...
#I think this shows some incorrect data on the weather API
#I converted the orientation so you can easily see the following:
#290 is showing as temp, humidity, and max temp.
#humid = data3.loc[data3["Humidity"] > 200]
#humid1 = humid.T
#humid1
from IPython.display import Image
Image(filename="Paita_Outlier.png")

# %%
Image(filename="PaitaDF.png")
